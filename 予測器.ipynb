# %% [markdown]
# <a href="https://colab.research.google.com/github/arumajirou/-daily-test/blob/main/%E4%BA%88%E6%B8%AC%E5%99%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cython
# !pip install numba
# %load_ext Cython
from numba import jit
# !pip install gputil
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=7b085ffddee830ca48b2af9166b38f5053734b74e33b689346872ab0ab257626
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built gputil
# ...

# %%
# # ライブラリのインポート
# import psutil
# import humanize
# import os
# import GPUtil as GPU

# # RAMの使用状況を取得
# def printm():
#     process = psutil.Process(os.getpid())
#     print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " | Proc size: " + humanize.naturalsize(process.memory_info().rss))
#     print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))

# # GPUの使用状況を取得
# gpu = GPU.getGPUs()[0]

# # 使用状況を表示
# printm()

# %%
# ライブラリのインポート
import psutil

# CPUの使用率を取得
def print_cpu_usage():
    print("CPU usage: {}%".format(psutil.cpu_percent(interval=1)))

# 使用率を表示
print_cpu_usage()
# Out:
# CPU usage: 4.5%

# %%
# %%time
#@title ドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CPU times: user 1.09 s, sys: 126 ms, total: 1.22 s
# Wall time: 1min 3s

# %%
#@title uvの設定
# !pip install uv
# !uv venv
# On macOS and Linux.
# !source .venv/bin/activate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 21.8 MB/s eta 0:00:00
# ...
# Using Python 3.10.12 interpreter at: /usr/bin/python3
# Creating virtualenv at: .venv
# Activate with: source .venv/bin/activate

# %%
# %%time
#@title uvの設定

#@title インストール
# !uv pip install -U causal-learn
# !uv pip install -U dowhy
# !uv pip install -U pycdt
# !uv pip install -U causallib
# !uv pip install -U networkx
# !uv pip install -U node2vec
# !uv pip install -U karateclub
# !uv pip install -U nashpy
# !uv pip install -U eppy
# !uv pip install -U feature_engine
# !uv pip install -U pycatch22
# !uv pip install -U pyts
# !uv pip install -U stumpy
# !uv pip install -U sktime
# !uv pip install -U cesium
# !uv pip install -U statsmodels
# !uv pip install -U tensorflow-probability
# !uv pip install -U problog
# !uv pip install -U pyro-ppl
# !uv pip install -U tsfresh
# !uv pip install -U featuretools
# !uv pip install -U pandas
# !uv pip install -U urllib3
# !uv pip install -U dask
# !uv pip install -U dask-ml
# !uv pip install -U kneed
# !uv pip install -U ruptures
# !uv pip install -U persim
# !uv pip install -U pywavelets
# !uv pip install -U scipy
# !uv pip install -U scikit-learn
# !uv pip install -U hmmlearn
# !uv pip install -U torch torchvision
# !uv pip install -U neuralforecast
# !uv pip install -U japanera
# !uv pip install -U polars
# !uv pip install -U autofeat
# !uv pip install -U CausalImpact
# !uv pip install -U pyfinance
# !uv pip install -U THINC
# !uv pip install -U hurst
# !uv pip install -U tsfedl
# !uv pip install -U egttools
# !uv pip install -U gambit
# !uv pip install -U pyentrp
# !uv pip install -U nolds
# !uv pip install -U tsml
# !uv pip install -U seglearn
# !uv pip install -U bnlearn
# !uv pip install -U dask[dataframe]
# !uv pip install -U mkl
# !uv pip install -U numpy
# !uv pip install -U ripser
# !uv pip install -U scipy
# !uv pip install -U jpholiday
# !uv pip install -U  tensorflow
# !uv pip install -U  tslearn
# Out:
# Resolved 36 packages in 691ms
# Downloaded 36 packages in 7.09s
# Installed 36 packages in 649ms
#  + causal-learn==0.1.3.8
#  + clarabel==0.7.1
#  + contourpy==1.2.1
#  + cvxpy==1.4.2
#  + cycler==0.12.1
#  + cython==3.0.10
#  + dowhy==0.11.1
#  + ecos==2.0.13
#  + fonttools==4.51.0
#  + graphviz==0.20.3
#  + joblib==1.4.0
#  + kiwisolver==1.4.5
#  + matplotlib==3.8.4
#  + mpmath==1.3.0
#  + networkx==3.3
#  + numpy==1.26.4
#  + osqp==0.6.4
#  + packaging==24.0
#  + pandas==2.2.2
#  + patsy==0.5.6
#  + pillow==10.3.0
#  + pybind11==2.12.0
#  + pydot==2.0.0
#  + pyparsing==3.1.2
#  + python-dateutil==2.9.0.post0
#  + pytz==2024.1
#  + qdldl==0.1.7.post1
#  + scikit-learn==1.4.2
#  + scipy==1.13.0
#  + scs==3.2.4.post1
#  + six==1.16.0
#  + statsmodels==0.14.1
#  + sympy==1.12
#  + threadpoolctl==3.4.0
#  + tqdm==4.66.2
#  + tzdata==2024.1
# Resolved 40 packages in 1.40s
# Building pycdt==2.0.2
# Building pycdt==2.0.2
# Building pycdt==2.0.2
# Building pycdt==2.0.2
# ...

# %%
# %%time
#@title pipでのインストール
# !pip install -U japanera
# !pip install -U pyprobables
# !pip install -U ray
# !pip install -U neuralforecast

# %%
# %%time


#@title インポート
# Pythonにパッケージの場所を教えます
import os
import sys
sys.path.append('/content/.venv/lib/python3.10/site-packages')

import pandas as pd
import jpholiday
# データ取得
import urllib.request  # URLを扱うためのライブラリ
from io import StringIO  # メモリ上のテキストストリームを扱うためのライブラリ

# 分散データ処理
import dask.dataframe as dd  # 大規模データの並列処理を行うためのライブラリ
from dask.distributed import Client  # Daskの分散コンピューティング環境を管理するためのライブラリ

# 日本語処理
import japanera  # 日本の元号を扱うためのライブラリ

# タイプヒント
from typing import List, Dict, Tuple, Optional  # 型ヒントを提供するためのライブラリ

# データ表示
import ipywidgets as widgets  # 対話的なウィジェットを作成するためのライブラリ
from IPython.display import display, HTML  # Jupyter環境での出力表示を制御するためのライブラリ

# 特徴量エンジニアリング
import featuretools as ft  # 自動的な特徴量生成を行うためのライブラリ
# import autofeat  # 自動的な特徴量生成と選択を行うためのライブラリ
from tsfresh import extract_features  # 時系列データから特徴量を抽出するためのライブラリ

# 機械学習と統計
import statsmodels.api as sm  # 統計モデルを扱うためのライブラリ
from sklearn import datasets  # scikit-learnが提供するデータセット
# import dask_ml.model_selection as dcv  # Daskを使用した機械学習のためのライブラリ
from kneed import KneeLocator  # Knee point（膝点）を見つけるためのライブラリ
from scipy import stats  # 科学技術計算を行うためのライブラリ

# 時系列分析
import stumpy  # 時系列データ分析のためのライブラリ
import sktime  # 時系列分析のための統合フレームワーク
import cesium  # 時系列データ分析のためのライブラリ
import ruptures as rpt  # 変化点検出のためのライブラリ
import pywt  # 離散ウェーブレット変換を行うためのライブラリ
import hmmlearn.hmm as hmm  # 隠れマルコフモデルを扱うためのライブラリ
from hurst import compute_Hc  # Hurst指数を計算するためのライブラリ
# import tsml  # 時系列データマイニングのためのライブラリ
import seglearn  # 時系列データとシーケンス学習のためのライブラリ

# ディープラーニング
import torch  # ディープラーニングのためのライブラリ
# import torchvision  # 画像処理のためのライブラリ

# 因果推論
# import causallearn as cl  # 因果推論のためのライブラリ
import dowhy  # 因果推論のためのライブラリ
import pycdt  # 因果推論のためのライブラリ
import causallib  # 因果推論のためのライブラリ
from causalimpact import CausalImpact  # 因果影響分析のためのライブラリ

# ネットワーク分析
# import networkx as nx  # ネットワーク構造の分析と可視化のためのライブラリ
# from node2vec import Node2Vec  # ネットワークデータの埋め込み学習のためのライブラリ
# import karateclub  # ネットワーク埋め込みと非負値行列因子分解のためのライブラリ
import nashpy as nash  # ゲーム理論のためのライブラリ
# import gambit  # ゲーム理論のためのライブラリ
# import egttools  # 進化ゲーム理論のためのライブラリ

# 確率的プログラミング
import tensorflow_probability as tfp  # 確率的推論と統計的分析のためのライブラリ
# import problog  # 確率的論理プログラミングのためのライブラリ
# import pyro  # 確率的プログラミングのためのライブラリ

# 複雑系分析
# from persim import plot_diagrams  # 持続ホモロジーのためのライブラリ
# from pyentrp import entropy as ent  # エントロピー計算のためのライブラリ
import nolds  # 非線形ダイナミクスと複雑系分析のためのライブラリ

# 金融分析
import pyfinance  # 金融データ分析のためのライブラリ

# その他
# import eppy  # EnergyPlusの入出力ファイルを扱うためのライブラリ
import urllib3  # HTTPクライアントのためのライブラリ
# import pycatch22  # キャッチ22特徴セットを計算するためのライブラリ
import datetime
import shutil
from pathlib import Path
from tqdm.notebook import tqdm
import time
from ray import tune
import multiprocessing
from neuralforecast.core import NeuralForecast

from neuralforecast.auto import (
    AutoRNN,
    AutoLSTM,
    AutoGRU,
    AutoTCN,
    AutoDeepAR,
    AutoDilatedRNN,
    AutoMLP,
    AutoNBEATS,
    AutoNBEATSx,
    AutoNHITS,
    AutoTFT,
    AutoVanillaTransformer,
    AutoInformer,
    AutoAutoformer,
    AutoFEDformer,
    AutoPatchTST,
    AutoTimesNet,
    AutoStemGNN,
    AutoHINT
)

from tsfresh import extract_features

from kneed import KneeLocator
import ruptures as rpt
from ruptures.detection import Pelt
import numpy as np
from nolds import lyap_r, corr_dim
import pywt
from hmmlearn import hmm

from sklearn.feature_selection import mutual_info_classif
from sklearn.cluster import KMeans
from sklearn.linear_model import BayesianRidge
from sklearn.decomposition import PCA, FastICA
from sklearn.ensemble import IsolationForest
from sklearn.impute import SimpleImputer
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

from scipy.stats import norm, poisson, expon
from scipy.signal import find_peaks, find_peaks_cwt
from scipy import interpolate
from scipy import fftpack,signal,stats

# %%
#@title データの作成

@jit(nopython=True)
def get_rokuyo(japanese_date) -> str:
    '''
    この関数は、日本の日付を受け取り、それを旧暦に変換し、対応する六曜を返します。

    :param japanese_date: 変換する日本の日付。
    :type japanese_date: japanera.JapaneseDate
    :return: 対応する六曜。
    :rtype: str
    '''
    # 日本の日付を旧暦に変換します。
    old_date = japanese_date.to_julian_date()

    # 旧暦の日と月を足し算します。
    month_day = int(old_date) % 100 + int(old_date * 100) % 100

    # 足し算した結果を6で割った余りを計算します。
    remainder = month_day % 6

    # 六曜のリストを定義します。これは日本の伝統的なカレンダーシステムです。
    rokuyo_list = ["大安", "赤口", "先勝", "友引", "先負", "仏滅"]

    # 余りの数に対応する六曜をリストから選び、それを返します。
    return rokuyo_list[remainder]

#@jit(nopython=True)
def make_numbers(num: int) -> pd.DataFrame:
    '''
    この関数は、指定したナンバーズ（数値型）をウェブから取得し、pandasのデータフレームに格納します。

    :param num: ウェブから取得するナンバーズの種類を指定します。int型。
    :return: 取得したナンバーズのデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # 指定されたナンバーズのデータをウェブから読み込みます。読み込んだデータはshift-jisでエンコードされています。
    df = pd.read_table('http://vvslot.com/download.php?m=777&f=numbers' + str(num) + '.txt', encoding="shift-jis", sep=",", names=["part", "date", "week", "eto", "抽選数字"], parse_dates=[1], dtype='object')

    # 新たなカラム"LOTO"を作成し、"num"と指定したナンバーズの種類（num）を連結した文字列を格納します。
    df["LOTO"] = "num" + str(num)

    # データフレームを"date"カラム（日付）に基づいてソート（並び替え）します。
    df = df.sort_values(by='date')

    # 抽選数字の各桁を新しいカラムに分割して格納します。例えば、抽選数字が"1234"の場合、"N1"には"1"、"N2"には"2"、"N3"には"3"、"N4"には"4"が格納されます。
    for i in range(4):
        df["N" + str(i + 1)] = df["抽選数字"].str[i]

    return df


#@jit(nopython=True)
def make_Bin5() -> pd.DataFrame:
    '''
    この関数は、ビンゴ5のデータをウェブから取得し、pandasのデータフレームに格納します。

    :return: 取得したビンゴ5のデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # ビンゴ5のデータをウェブから読み込みます。このデータはHTMLのテーブル形式です。
    url = 'http://vvslot.com/bingo5_data.php'
    df_Bin5 = pd.read_html(url)

    # 読み込んだデータ（HTMLのテーブル）の中から、10番目（インデックスは9）のテーブルを取得します。
    # 不要なカラム（"Ｎ5",'1等', '2等', '3等'）を削除します。
    df_Bin5 = df_Bin5[9].drop(["Ｎ5",'1等', '2等', '3等'], axis=1)

    # データフレームのカラム名を新しく設定します。
    df_Bin5.columns = ['part','date','N1','N2','N3','N4','N5','N6','N7','N8']

    # 'date'カラムのデータを日付型に変換します。この際、日付の形式を指定します。
    df_Bin5['date'] = pd.to_datetime(df_Bin5['date'], format='%Y年%m月%d日')

    # 新たなカラム"LOTO"を作成し、その値として"Bin5"を格納します。これは、このデータフレームがビンゴ5のデータであることを示します。
    df_Bin5["LOTO"] = "Bin5"

    return df_Bin5


#@jit(nopython=True)
def make_loto(name: str = "loto6", col: int = 9, ln: int = 6, b: int = 1) -> pd.DataFrame:
    '''
    この関数は、指定されたロト（例：loto6）のデータをウェブから取得し、pandasのデータフレームに格納します。

    :param name: 取得するロトの名前を指定します。デフォルトは"loto6"。str型。
    :param col: 取得するカラムの数を指定します。デフォルトは9。int型。
    :param ln: ナンバーの数を指定します。デフォルトは6。int型。
    :param b: ボーナスの数を指定します。デフォルトは1。int型。
    :return: 取得したロトのデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # データフレームのカラム名を作成します。"part"、"date"、ナンバー("N1"~"N6")、ボーナス("B1")を含みます。
    names = ["part", "date"] + ["N" + str(i) for i in range(1, ln + 1)] + ["B" + str(j) for j in range(1, b + 1)]

    # 指定されたロトのデータをウェブから読み込みます。読み込んだデータはshift-jisでエンコードされています。
    df = pd.read_table('https://' + name + '.thekyo.jp/data/' + name + '.csv', encoding="shift-jis",
 sep=",", skiprows=1, usecols=list(range(col)), parse_dates=[1], names=names)  # datetimeの選択

    # 新たなカラム"LOTO"を作成し、ロトの名前を格納します。これは、このデータフレームがどのロトのデータであることを示します。
    df["LOTO"] = name

    return df

@jit(nopython=True)
def one_hot_encode_week(df: pd.DataFrame) -> pd.DataFrame:
    '''
    この関数は、データフレームの'week'カラムをワンホットエンコーディングします。

    :param df: ワンホットエンコーディングを行うデータフレーム。pandas.DataFrame型。
    :return: 'week'カラムをワンホットエンコーディングしたデータフレーム。pandas.DataFrame型。
    '''
    # 'week'カラムの各値をワンホットエンコーディングします。これにより、'week'カラムの各値が新たなカラムとして追加されます。
    week_dummies = pd.get_dummies(df['week'], prefix='week')

    # オリジナルのデータフレームとワンホットエンコーディングしたデータフレームを連結します。
    df = pd.concat([df, week_dummies], axis=1)

    # 元の'week'カラムはもう必要ないので、データフレームから削除します。
    df.drop('week', axis=1, inplace=True)

    return df

# %%
# データフレームの作成
df_numbers4 = pd.DataFrame(make_numbers(4))  # ナンバーズ4のデータフレームを作成します
df_numbers3 = pd.DataFrame(make_numbers(3))  # ナンバーズ3のデータフレームを作成します
df_Bin5 = pd.DataFrame(make_Bin5())  # ビンゴ5のデータフレームを作成します
df_loto5 = pd.DataFrame(make_loto(name="miniloto", col=8, ln=5, b=1))  # ミニロトのデータフレームを作成します
df_loto6 = pd.DataFrame(make_loto())  # ロト6のデータフレームを作成します
df_loto7 = pd.DataFrame(make_loto(name="loto7", col=11, ln=7, b=2))  # ロト7のデータフレームを作成します

# データフレームの結合と日付での並び替え
df_sorted = pd.concat([df_loto5, df_loto6, df_loto7, df_numbers3, df_numbers4, df_Bin5]).sort_values('date')

# '抽選数字'カラムは不要なので削除します
df_sorted.drop('抽選数字', axis=1, inplace=True)

# データフレームを日付で並び替えます
df_sorted = df_sorted.sort_values(by='date')

# カテゴリ変数をワンホットエンコーディングします
df_encoded = pd.get_dummies(df_sorted, columns=['week', 'eto', 'LOTO'])

# Convert the num1 to num8 columns to integer type
df_encoded[['part','N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7','N8','B1', 'B2']] = df_encoded[['part','N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7','N8','B1', 'B2']].replace('missing', 0).replace([np.inf, -np.inf], np.nan).fillna(0).astype(int)


#@title データの情報
df_encoded.info()
#df_encoded=df_encoded[df_encoded.LOTO_Bin5 == 1]

# %%
#@title データフレームの作成
# セレクトボックスの選択肢を設定します。各選択肢は宝くじの種類を表しています。
options = [
 ("LOTO_num4", "LOTO_num4"),
 ("LOTO_num3", "LOTO_num3"),
 ("LOTO_Bin5", "LOTO_Bin5"),
 ("LOTO_loto6", "LOTO_loto6"),
 ("LOTO_loto7", "LOTO_loto7"),
 ("LOTO_miniloto", "LOTO_miniloto"),
]


# ドロップダウンメニューを作成します。ユーザーはこのメニューから宝くじの種類を選択します。
# デフォルトで"LOTO_Bin5"が選択されるようにvalueパラメータを設定します。
select_box = widgets.Dropdown(
 options=options,
 value="LOTO_num4",
 description='LOTO:',
 disabled=False,
)


# セレクトボックスを表示します。ユーザーが選択するためのものです。
display(select_box)

# フィルタリングされたデータフレームを格納するためのグローバル変数を宣言します。
global_filtered_df = None

from IPython.display import display, HTML
# @jit(nopython=True)
def filter_dataframe(change: dict = None) -> None:
 '''
 選択された宝くじの種類に応じてデータフレームをフィルタリングする関数

 Args:
 change (dict, optional): ドロップダウンメニューの値が変更されたときに生成される辞書型のデータ。
 'new'キーは新しく選択された値を表します。デフォルトはNone。

 Returns:
 None: この関数は何も返しません。ただし、グローバル変数global_filtered_dfが更新されます。
 '''
 # グローバル変数を参照します
 global global_filtered_df
 # ドロップダウンメニューで新しく選択された宝くじの種類を取得します
 # changeがNoneの場合、デフォルトで"LOTO_num4"を選択します
 selected_column = change['new'] if change else "LOTO_num4"
 # データフレームをフィルタリングします。
 # 選択された宝くじの種類の列が1の行だけを残します。
 try: # ここからエラーハンドリングを追加
     global_filtered_df = df_encoded[df_encoded[selected_column] == 1]
 except NameError as e: # df_encodedが未定義の場合に発生する例外
     print(f"データフレームdf_encodedが未定義です。{e}")
 except KeyError as e: # 選択された宝くじの種類の列が存在しない場合に発生する例外
     print(f"データフレームdf_encodedに{selected_column}という列がありません。{e}")
 else: # 例外が発生しなかった場合に実行する処理
     # フィルタリングされたデータフレームをHTMLテーブルとして表示します。
     display(HTML(global_filtered_df.head().to_html()))
 finally: # 例外の有無に関わらず必ず実行する処理
     print(f"{selected_column}でフィルタリングしました。")

#@jit(nopython=True)
def select_df():
  '''
  セレクトボックスを表示し、ユーザーが宝くじの種類を選択できるようにする関数

  引数: なし
  戻り値: なし
  '''
  # セレクトボックスを表示します。ユーザーが選択するためのものです。
  display(select_box)

  # 選択された宝くじの種類が変わったときに上記の関数を呼び出すように設定します。
  # この操作は「observe」と呼ばれ、ドロップダウンメニューの値が変更されるたびにfilter_dataframe関数が呼び出されるようにします。
  select_box.observe(filter_dataframe, names='value')

  # 初期状態でfilter_dataframe関数を呼び出し、デフォルトの"LOTO_Bin5"でフィルタリングします。
  filter_dataframe()

# %%
select_df()

# %%
# %%time
#@title カラムのチェック
columns_to_check = ["LOTO_Bin5", "LOTO_loto6", "LOTO_loto7", "LOTO_miniloto", "LOTO_num3", "LOTO_num4"]

# Trueになっているカラム名を見つける
true_columns = global_filtered_df[columns_to_check].apply(lambda row: row[row == True].index.tolist(), axis=1)

# 結果を変数に格納
true_column_names = true_columns.tolist()[0][0]

# 結果を表示
print(true_column_names)

# %%
# %%time
#@title　予測データの絞り込み

# 選択可能なカラムのリストを作成します
columns = ['N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'B1', 'B2']

# プルダウンメニューを作成します
dropdown = widgets.Dropdown(options=columns)

# 出力エリアを作成します
output = widgets.Output()

# 選択したデータフレームを保存するための変数を作成します
selected_df_pre = None

# 選択したカラムを保存するための変数を作成します
selected_column = None

# プルダウンメニューの値が変更されたときの動作を定義します

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        # 出力エリアをクリアします
        output.clear_output()

    # 選択したカラムとdateカラムのデータフレームを作成します
    global selected_df_pre, selected_column
    selected_column = change['new']
    selected_df_pre = global_filtered_df[['date', selected_column]]

    # 新しいデータフレームを表示します
    with output:
        display(selected_df_pre)
    return selected_df_pre
# プルダウンメニューの値が変更されたときにon_change関数を呼び出します
dropdown.observe(on_change)

# プルダウンメニューと出力エリアを表示します
display(dropdown)
display(output)

# デフォルトでリストの最初の項目を選択します
dropdown.value = columns[0]
on_change({'type': 'change', 'name': 'value', 'new': columns[0]})

# %%
#@title データの情報
# pandasのto_datetime関数を使用して、dateカラムを日時型に変換します
global_filtered_df['date'] = pd.to_datetime(global_filtered_df['date'])

# dateカラムのデータ型を確認します
print(global_filtered_df['date'].dtype)

global_filtered_df.info()

# %%
import pandas as pd

# ワンホットエンコーディング
one_hot = pd.get_dummies(global_filtered_df[selected_column])

# エンコーディング結果を元のデータフレームに結合
global_filtered_df = pd.concat([global_filtered_df, one_hot], axis=1)

# エンコーディング後のデータフレームを表示
global_filtered_df.info()

# %%
#@title カラムの組み合わせによる特徴量を抽出
# 偶数の列のインデックスを取得
even_cols = [i for i in range(10) if i % 2 == 0]

# 偶数の列の合計を計算し、新しい列に追加
global_filtered_df['even_sum'] = global_filtered_df.loc[:, even_cols].sum(axis=1)

# 奇数の列のインデックスを取得
odd_cols = [i for i in range(10) if i % 2 != 0]

# 奇数の列の合計を計算し、新しい列に追加
global_filtered_df['odd_sum'] = global_filtered_df.loc[:, odd_cols].sum(axis=1)

# 特定の列の組み合わせを定義
specific_cols = [2, 3, 5, 7]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['prime'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
# 特定の列の組み合わせを定義
specific_cols = [1,2,3,4,5]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num1_5'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
# 特定の列の組み合わせを定義
specific_cols = [6,7,8,9,0]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num6_0'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [1,2,3]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num1_3'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [4,5,6]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num4_6'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [7,8,9]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num7_9'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [1,2]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num1_2'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [3,4]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num3_4'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [5,6]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num5_6'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [7,8]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num7_8'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [9,0]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num9_0'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [1,0]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num1_0'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [2,9]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num2_9'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [3,8]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num3_8'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [4,7]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num4_7'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)
specific_cols = [5,6]
# 特定の列の合計を計算し、新しい列に追加
global_filtered_df['num5_6'] = global_filtered_df.loc[:, specific_cols].sum(axis=1)

global_filtered_df.columns

# %%
#@title 隠れマルコフモデルでの特徴量を抽出
# %%time

import pandas as pd
import numpy as np
from hmmlearn import hmm

# 元のデータフレームをコピー
hmm_df_pre = global_filtered_df.copy()

# n_componentsを1から10まで変化させる
for n in range(1, 11):
    # 隠れマルコフモデルのインスタンスを作成
    model = hmm.GaussianHMM(n_components=n, covariance_type="full")  # n_componentsは隠れた状態の数を表します

    # モデルの学習
    model.fit(hmm_df_pre[[selected_column]])  # 'N1'は学習に使用する特徴量を表します

    # 状態の予測
    hmm_df_pre['hidden_state_'+str(n)] = model.predict(hmm_df_pre[[selected_column]])  # 各n_componentsに対する隠れた状態を予測し、新たな列としてデータフレームに追加します

# 結果の表示
hmm_df_pre

# %%
true_column_names

# %%
# %%time

#@title 条件付確率を追加
# 既存のデータフレームを仮定します
prob_df= global_filtered_df.copy()

# 新しいデータフレームを作成します
df_features = pd.DataFrame()
print(global_filtered_df[selected_column].dtype)  # データ型を確認

# データ型がobjectやstrの場合、数値に変換
if global_filtered_df[selected_column].dtype == 'object':
    global_filtered_df[selected_column] = pd.to_numeric(global_filtered_df[selected_column], errors='coerce')

# 統計的特徴量を抽出します
df_features['N1_mean'] = [np.mean(global_filtered_df[selected_column])] * len(global_filtered_df)
df_features['N1_median'] = [np.median(global_filtered_df[selected_column])] * len(global_filtered_df)
df_features['N1_stddev'] = [np.std(global_filtered_df[selected_column])] * len(global_filtered_df)
df_features['N1_variance'] = [np.var(global_filtered_df[selected_column])] * len(global_filtered_df)

# 確率的特徴量を抽出します
# ここでは、N1が正規分布に従うかどうかを確認します
mu = np.mean(global_filtered_df[selected_column])
sigma = np.std(global_filtered_df[selected_column])
df_features['N1_normal_likelihood'] = stats.norm.pdf(global_filtered_df[selected_column], loc=mu, scale=sigma)

# 新しい特徴量を元のデータフレームに追加します
prob_df= pd.concat([global_filtered_df, df_features], axis=1)
# 論理的特徴量を抽出します
# ここでは、N1が偶数であるかどうかを確認します
df_features['N1_is_even'] = global_filtered_df[selected_column] % 2 == 0

# 新しいデータフレームを作成します
df_features = pd.DataFrame()
# 各カラムの値とN1の値の条件付確率を特徴量抽出として追加します
for column in global_filtered_df.columns:
    if column != 'N1':
        # 条件付き確率 P(N1 | column) を計算します
        joint_counts = pd.crosstab(global_filtered_df[column], global_filtered_df[selected_column])
        conditional_prob = joint_counts.div(joint_counts.sum(axis=1), axis=0)

        # 条件付き確率を新しい特徴量として追加します
        for n1_value in conditional_prob.columns:
            df_features[f'P(N1={n1_value}|{column})'] = global_filtered_df[column].map(conditional_prob[n1_value])


# 新しい特徴量を元のデータフレームに追加します
prob_df= pd.concat([global_filtered_df, df_features], axis=1)
prob_df

# %%
# %%time
import stumpy
import numpy as np

# あなたのデータフレームをdfと仮定します
stumpy_df = global_filtered_df.copy()

# 'N1'カラムのデータ型をnumpy.float64に変換
stumpy_df[selected_column] = stumpy_df[selected_column].astype(np.float64)

# ウィンドウサイズのリスト
window_sizes = [i for i in range(3, 101)]
print(window_sizes)

for window in window_sizes:
    matrix_profile = stumpy.stump(stumpy_df[selected_column], m=window)
    stumpy_df.loc[stumpy_df.index[window - 1:], f'feature_{selected_column}_window_{window}'] = matrix_profile[:, 0]

stumpy_df.tail()

# %%
#@title featuretoolsを追加
# Feature extraction with Featuretools
featuretools_df = global_filtered_df.copy()
print(featuretools_df.columns)
# Convert all column names to string
featuretools_df.columns = featuretools_df.columns.astype(str)

# Now you can add the dataframe to the entity set
es = ft.EntitySet(id='data')
es = es.add_dataframe(dataframe_name='data', dataframe=featuretools_df, index='index')

features, feature_defs = ft.dfs(entityset=es, target_dataframe_name='data')
featuretools_df = featuretools_df.merge(features, left_index=True, right_index=True)
featuretools_df
print(featuretools_df.columns)
featuretools_df

# %%
global_filtered_df

# %%
# %%time

#@title TSFreshで特徴量を追加
tsfresh_df = global_filtered_df[['date',selected_column]]


tsfresh_df = tsfresh_df.apply(pd.to_numeric, errors='coerce')

print(tsfresh_df.columns)
# TSFreshで特徴量を抽出
extracted_features = extract_features(tsfresh_df, column_id='date', column_sort='date')
tsfresh_df = tsfresh_df.merge(extracted_features, left_on='date', right_index=True)
tsfresh_df
print(tsfresh_df.columns)

# %%
selected_df= global_filtered_df.copy()
target_column = selected_column
# Convert the target column to a numeric data type
selected_df[target_column] = pd.to_numeric(selected_df[target_column], errors='coerce')
selected_df

# %%
additional_columns = ['even_sum', 'odd_sum', 'prime', 'num1_5', 'num6_0', 'num1_3', 'num4_6', 'num7_9', 'num1_2', 'num3_4', 'num5_6', 'num7_8', 'num9_0', 'num1_0', 'num2_9', 'num3_8', 'num4_7']

for column in tqdm(additional_columns):
    # 数値に変換
    selected_df[column] = pd.to_numeric(selected_df[column], errors='coerce')

    # 各種統計量を計算
    selected_df[f'{column}_mean'] = selected_df[column].mean()
    selected_df[f'{column}_median'] = selected_df[column].median()
    selected_df[f'{column}_max'] = selected_df[column].max()
    selected_df[f'{column}_min'] = selected_df[column].min()

    # 移動平均、ラグ特徴量、指数平滑、指数加重移動平均を計算
    for i in range(1, 101):
        selected_df[f'{column}_rolling_mean_{i}'] = selected_df[column].rolling(window=i).mean()
        selected_df[f'{column}_lag_{i}'] = selected_df[column].shift(i)
        selected_df[f'{column}_ewm_{i}'] = selected_df[column].ewm(span=i).mean()
        selected_df[f'{column}_ewma_{i}'] = selected_df[column].ewm(halflife=i).mean()
        # データの滑らかさを計算
        selected_df[f'{column}_smoothness'] = selected_df[column].rolling(window=i).mean()
        # データの不規則性を計算
        selected_df[f'{column}_irregularity'] = selected_df[column].rolling(window=i).std()
    # FFTに基づく特徴量を計算
    fft_coeff = fftpack.fft(selected_df[column])
    selected_df[f'{column}_fft_coeff'] = np.abs(fft_coeff)

    # トレンド成分を計算
    slope, _, _, _, _ = stats.linregress(np.arange(len(selected_df)), selected_df[column])
    selected_df[f'{column}_trend'] = slope

    # 分散を計算
    selected_df[f'{column}_variance'] = selected_df[column].var()

    # ピーク間の距離を計算
    peaks, _ = find_peaks(selected_df[column])
    selected_df[f'{column}_peak_distance'] = np.diff(peaks).mean()

    # ヒストグラムベースの特徴量を計算
    hist, bins = np.histogram(selected_df[column], bins=10)
    selected_df[f'{column}_hist_bin_count'] = len(hist)
    selected_df[f'{column}_hist_bin_width'] = np.diff(bins).mean()

    # Zスコアを計算
    selected_df[f'{column}_z_score'] = stats.zscore(selected_df[column])

    # データの尖度を計算
    selected_df[f'{column}_kurtosis'] = selected_df[column].kurtosis()

    # データの歪度を計算
    selected_df[f'{column}_skewness'] = selected_df[column].skew()

    # データのエントロピーを計算
    selected_df[f'{column}_entropy'] = stats.entropy(selected_df[column])

# カラムの値が1つしかないカラムを削除
selected_df = selected_df.loc[:, selected_df.nunique() != 1]

# 数値型でないカラムを削除
selected_df = selected_df.select_dtypes(include=[np.number])
selected_df

# %%
for column in tqdm(additional_columns):
    # 数値に変換
    selected_df[column] = pd.to_numeric(selected_df[column], errors='coerce')

    # Box-Cox 変換
    selected_df[f'{column}_box_cox'], _ = stats.boxcox(selected_df[column] + 1)

    # 外れ値検出
    q1 = selected_df[column].quantile(0.25)
    q3 = selected_df[column].quantile(0.75)
    iqr = q3 - q1
    selected_df[f'{column}_outlier_flag'] = (selected_df[column] < (q1 - 1.5 * iqr)) | (selected_df[column] > (q3 + 1.5 * iqr))

    # 差分
    selected_df[f'{column}_diff'] = selected_df[column].diff()

    # 離散コサイン変換
    dct_coeff = fftpack.dct(selected_df[column])
    selected_df[f'{column}_dct_coeff'] = np.abs(dct_coeff)

    # 季節性分解
    result = seasonal_decompose(selected_df[column], model='additive', period=12)
    selected_df[f'{column}_trend'] = result.trend
    selected_df[f'{column}_seasonal'] = result.seasonal
    selected_df[f'{column}_resid'] = result.resid

    # ARIMAモデル
    model = ARIMA(selected_df[column], order=(1, 1, 1))
    model_fit = model.fit()
    selected_df[f'{column}_arima_pred'] = model_fit.predict()
    selected_df[f'{column}_arima_resid'] = selected_df[column] - selected_df[f'{column}_arima_pred']

    # 正規分布
    mu, std = norm.fit(selected_df[column])
    selected_df[f'{column}_norm_pdf'] = norm.pdf(selected_df[column], loc=mu, scale=std)
    selected_df[f'{column}_norm_cdf'] = norm.cdf(selected_df[column], loc=mu, scale=std)

    # ポアソン分布
    lam = selected_df[column].mean()
    selected_df[f'{column}_poisson_pmf'] = poisson.pmf(selected_df[column], mu=lam)
    selected_df[f'{column}_poisson_cdf'] = poisson.cdf(selected_df[column], mu=lam)

    # 指数分布
    loc, scale = expon.fit(selected_df[column])
    selected_df[f'{column}_expon_pdf'] = expon.pdf(selected_df[column], loc=loc, scale=scale)
    selected_df[f'{column}_expon_cdf'] = expon.cdf(selected_df[column], loc=loc, scale=scale)

    # バターワースフィルタ
    nyq = 0.5 * len(selected_df)
    normalized_cutoff = 0.1 / nyq
    order = 4
    normalized_b, normalized_a = signal.butter(order, normalized_cutoff, btype='low', analog=False)
    filtered = signal.filtfilt(normalized_b, normalized_a, selected_df[column])
    selected_df[f'{column}_butterworth_filtered'] = filtered

    # パワースペクトル密度
    freqs, psd = signal.welch(selected_df[column], fs=1.0, nperseg=100)
    selected_df[f'{column}_psd_peak_freq'] = freqs[np.argmax(psd)]
    selected_df[f'{column}_psd_peak_power'] = np.max(psd)

# %%
for column in tqdm(additional_columns, desc="Processing columns"):
    # 数値に変換
    selected_df[column] = pd.to_numeric(selected_df[column], errors='coerce')

    # ウェーブレット変換
    wavelet = 'db4'  # 或いは 'sym4', 'coif3' など
    coeffs = pywt.wavedec(selected_df[column], wavelet)
    for i in range(len(coeffs)):
        coeff_padded = np.full_like(selected_df[column], fill_value=np.nan)
        coeff_padded[:len(coeffs[i])] = coeffs[i]
        selected_df[f'{column}_wavelet_coeffs_{i}'] = coeff_padded

    # HMM
    remodel = hmm.GaussianHMM(n_components=3, covariance_type="full", n_iter=1000)
    remodel.fit(selected_df[column].values.reshape(-1, 1))
    for i in range(remodel.n_components):
        selected_df[f'{column}_hmm_mean_{i}'] = remodel.means_[i][0]
        selected_df[f'{column}_hmm_var_{i}'] = np.diag(remodel.covars_[i])[0]

    # KDE
    kde = stats.gaussian_kde(selected_df[column])
    selected_df[f'{column}_kde_peak'] = kde.pdf(selected_df[column]).max()
    selected_df[f'{column}_kde_mean'] = kde.pdf(selected_df[column]).mean()
    selected_df[f'{column}_kde_var'] = kde.pdf(selected_df[column]).var()

# %%
from scipy.interpolate import interp1d

for column in tqdm(additional_columns):
    # 数値に変換
    selected_df[column] = pd.to_numeric(selected_df[column], errors='coerce')

    # ピークと谷の検出
    peaks, _ = find_peaks(selected_df[column])
    selected_df[f'{column}_num_peaks'] = len(peaks)
    selected_df[f'{column}_mean_peak_height'] = selected_df.loc[peaks, column].mean()

    valleys, _ = find_peaks(-selected_df[column])
    selected_df[f'{column}_num_valleys'] = len(valleys)
    selected_df[f'{column}_mean_valley_depth'] = -selected_df.loc[valleys, column].mean()

    # 補間
    interp_func = interp1d(selected_df.index, selected_df[column], kind='cubic')
    selected_df[f'{column}_interpolated'] = interp_func(selected_df.index)
    selected_df[f'{column}_interp_diff'] = selected_df[column] - selected_df[f'{column}_interpolated']

    # ピーク比率
    selected_df[f'{column}_peak_ratio'] = selected_df[f'{column}_num_peaks'] / selected_df[f'{column}_mean_peak_height']

# %%
max_tau = 10
embd_dim = 5
lyap_exp = lyap_r(selected_df[target_column].values, embd_dim, max_tau)
selected_df['lyapunov_exponent'] = lyap_exp

dimension = corr_dim(selected_df[target_column].values, embd_dim)
selected_df['correlation_dim'] = dimension

# %%
# RBFカーネルを使用
kernel = RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e3)) \
  + WhiteKernel(noise_level=1, noise_level_bounds=(1e-10, 1e+1))

gp = GaussianProcessRegressor(kernel=kernel)
gp.fit(selected_df.index.values.reshape(-1, 1), selected_df[target_column].values)

selected_df['gp_mean'] = gp.predict(selected_df.index.values.reshape(-1, 1))
selected_df['gp_std'] = np.sqrt(gp.kernel_.diag(selected_df.index.values.reshape(-1, 1)))

# %%
# global_filtered_dfのカラム名を取得
global_columns = global_filtered_df.columns

# 各データフレームからglobal_filtered_dfのカラム名以外のカラムを抽出
tsfresh_df_filtered = tsfresh_df[tsfresh_df.columns.difference(global_columns)]
featuretools_df_filtered = featuretools_df[featuretools_df.columns.difference(global_columns)]
prob_df_filtered = prob_df[prob_df.columns.difference(global_columns)]
hmm_df_pre_filtered = hmm_df_pre[hmm_df_pre.columns.difference(global_columns)]
selected_dff_pre_filtered = selected_df[selected_df.columns.difference(global_columns)]

# すべてのデータフレームを結合
merged_df = pd.concat([global_filtered_df, tsfresh_df_filtered, featuretools_df_filtered, prob_df_filtered, hmm_df_pre_filtered,selected_dff_pre_filtered], axis=1)
print(f"merged_df={len(merged_df.columns)}")
merged_df

# %%
import itertools
def remove_constant_columns(df):
    return df.loc[:, (df != df.iloc[0]).any()]
merged_df = remove_constant_columns(merged_df)
# 各列の最頻値を計算します。
mode = merged_df.mode().iloc[0]
# merged_df = merged_df.dropna(how='all', axis=1)

# fillnaメソッドを使用して、各列のNaNをその列の最頻値で置き換えます。
merged_df = merged_df.fillna(mode)
merged_df = merged_df.dropna(how='any', axis=1)
merged_df = merged_df.astype(int)

print("重複した列を削除した後のDataFrame:")
print(merged_df)
def remove_duplicate_columns(df):
    cols = pd.Series(df.columns)
    for dup in cols[cols.duplicated()].unique():
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    df.columns = cols
    return df

merged_df = remove_duplicate_columns(merged_df)


print("NaNを最頻値で置き換えた後のDataFrame:")
merged_df
assert not np.any(pd.isnull(merged_df))
merged_df["date"]=global_filtered_df["date"]
merged_df

# %%
# %%time

try:
    # 欠損値を持つカラムを削除
    # merged_df = merged_df.dropna(how='all', axis=1)
    # 数値型のカラムだけに対してfillnaを適用
    num_cols = merged_df.select_dtypes(include=[np.number]).columns
    merged_df[num_cols] = merged_df[num_cols].fillna(merged_df[num_cols].mean())

    # カテゴリ型のカラムに対しては最頻値で補完
    cat_cols = merged_df.select_dtypes(include=['category']).columns
    merged_df[cat_cols] = merged_df[cat_cols].fillna(merged_df[cat_cols].mode().iloc[0])
    print(f"カラム＝{merged_df.columns}\nカラムの数={len(merged_df.columns)}")
    print(merged_df.info())
    # NaNや無限大の値が含まれていないことを確認

    assert not np.any(pd.isnull(merged_df[num_cols]))
    assert np.all(np.isfinite(merged_df[num_cols]))
    # Combine numerical and categorical columns
    num_cat_cols = num_cols.union(cat_cols)
    # 特徴量と目的変数との相互情報量を計算
    X = merged_df[num_cat_cols].drop(target_column, axis=1)
    print(f"X={X}")
    y = merged_df[target_column]
    print(f"y={y}")
    mutual_info = mutual_info_classif(X, y)
    print(f"mutual_info={mutual_info}")
    # 相互情報量が高い特徴量を選択
    feature_scores = pd.Series(mutual_info, index=X.columns)
    print(f"feature_scores={feature_scores}")
    # 寄与率の閾値を設定
    threshold = 0.1

    # 寄与率が閾値以上の特徴量を選択
    selected_features = feature_scores[feature_scores > threshold].index
    print(f"selected_features={len(selected_features)}")
    # 選択した特徴量のみを含むデータフレームを作成
    merged_df = merged_df[selected_features.tolist() + [target_column]]
    csv_path=f'/content/drive/MyDrive/{true_column_names}_{selected_column}.csv'
    selected_df.to_csv(csv_path, index=False)

except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# エラーが発生しました: name 'merged_df' is not defined
# CPU times: user 1.4 ms, sys: 0 ns, total: 1.4 ms
# Wall time: 2.08 ms

# %%
# %%time
merged_df["date"]=global_filtered_df["date"]
selected_df = merged_df.sort_index()
selected_df = merged_df.rename(columns={selected_column: 'y', 'date': 'ds'})
selected_df["unique_id"]=0
# 重複したカラムを削除
selected_df = selected_df.loc[:,~selected_df.columns.duplicated()]

# 'y'と'ds'というカラムが存在するか確認
if 'y' in selected_df.columns and 'ds' in selected_df.columns and 'unique_id' in selected_df.columns:
    print("'y'と'ds'と'unique_id'のカラムが存在します。")
else:
    print("'y'と'ds'と'unique_id'のカラムが存在しません。")
    merged_df["date"]=global_filtered_df["date"]
    selected_df = merged_df.sort_index()
    selected_df = merged_df.rename(columns={selected_column: 'y', 'date': 'ds'})
# Out:
# 'y'と'ds'と'unique_id'のカラムが存在します。
# CPU times: user 161 ms, sys: 964 µs, total: 161 ms
# Wall time: 161 ms
# <timed exec>:1: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
#@title 特徴量の可視化
# %matplotlib inline
import plotly.express as px

# 寄与率をデータフレームに変換
df = pd.DataFrame({'Feature': selected_features, 'Importance': feature_scores[selected_features]})
print(f"selected_features={len(selected_features)}")
# データフレームを寄与率でソート
df = df.sort_values('Importance', ascending=False)

# バープロットを作成
fig = px.bar(df, x='Importance', y='Feature', orientation='h', title='Feature Importances')

# プロットを表示
fig.show()
# Out:
# selected_features=1475
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# %%time
import pandas as pd
import numpy as np
from sklearn import preprocessing

# selected_df.yの値を取得
y = selected_df['y'].values

# 正則化
y_regularized = y / np.linalg.norm(y)

# 正規化
min_max_scaler = preprocessing.MinMaxScaler()
y_normalized = min_max_scaler.fit_transform(y.reshape(-1,1))

# 標準化
standard_scaler = preprocessing.StandardScaler()
y_standardized = standard_scaler.fit_transform(y.reshape(-1,1))
# 正則化した値を新たなカラムとして追加
selected_df['y_regularized'] = y_regularized

# 正規化した値を新たなカラムとして追加
selected_df['y_normalized'] = y_normalized

# 標準化した値を新たなカラムとして追加
selected_df['y_standardized'] = y_standardized
# Out:
# CPU times: user 3.52 ms, sys: 91 µs, total: 3.61 ms
# Wall time: 3.36 ms

# %%
#@title データの分割
selected_df_3=selected_df[["y","ds","unique_id"]]
# テストデータのサイズ
test_size = 5

# データを訓練データとテストデータに分割します
Y_train_df = selected_df.iloc[:-test_size]
Y_test_df = selected_df.iloc[-test_size:]

print(f"訓練データの数: {len(Y_train_df)}")
print(f"テストデータの数: {len(Y_test_df)}")
print(f"カラムの数: {len(Y_test_df.columns)}")
Y_test_df
# Out:
# 訓練データの数: 6440
# テストデータの数: 5
# カラムの数: 1480
#       N1__abs_energy  N1__abs_energy_1  N1__absolute_maximum  \
# 6440             9.0               9.0                   3.0
# 6441             4.0               4.0                   2.0
# 6442             1.0               1.0                   1.0
# 6443            16.0              16.0                   4.0
# 6444             4.0               4.0                   2.0
#
#       N1__absolute_maximum_1  N1__benford_correlation  \
# 6440                     3.0                 0.062915
# 6441                     2.0                 0.295657
# 6442                     1.0                 0.864123
# 6443                     4.0                -0.064614
# 6444                     2.0                 0.295657
#
#       N1__benford_correlation_1  N1__count_below__t_0  N1__count_below__t_0_1  \
# 6440                   0.062915                   0.0                     0.0
# ...

# %%
#@title モデル定義


cpus = multiprocessing.cpu_count()
gpus = torch.cuda.device_count()
horizon=2

freq='D'

models =[
    AutoRNN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoLSTM(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoGRU(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTCN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoDeepAR(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoDilatedRNN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoMLP(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNBEATS(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNBEATSx(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNHITS(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTFT(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoVanillaTransformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoInformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoAutoformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoFEDformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    #AutoPatchTST(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTimesNet(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoStemGNN(config=None, n_series=1, h=horizon, cpus=cpus, gpus=gpus, verbose=False)
    # AutoHINT(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
]

# %%
start_time = time.time()
elapsed_time = time.time() - start_time
elapsed_time_str = str(datetime.timedelta(seconds=int(elapsed_time)))
print(f"{model.__class__.__name__}の処理時間: {elapsed_time_str}")

# %%
#@title データ予測

# 'standard': 標準化スケーラ（平均0、分散1にスケーリング）
# 'robust': ロバストスケーラ（中央値と四分位範囲に基づくスケーリング）
# 'robust-iqr': IQRロバストスケーラ（四分位範囲に基づくスケーリング）
# 'minmax': Min-Maxスケーラ（最小値0、最大値1にスケーリング）
# 'boxcox': Box-Cox変換（正規分布に近づけるための変換）
local_scaler_type ='standard'
feature=len(Y_test_df.columns)
try:
    pbar = tqdm(total=len(models), desc="モデルの処理")

    for model in models:
        start_time = time.time()
        print("+"*100)
        print(f"モデル名: {model.__class__.__name__}")
        print("+"*100)
        nf = NeuralForecast(models=[model], freq=freq, local_scaler_type=local_scaler_type)
        nf.fit(df=Y_train_df)
        elapsed_time = time.time() - start_time
        elapsed_time_str = str(datetime.timedelta(seconds=int(elapsed_time)))
        print(f"{model.__class__.__name__}の処理時間: {elapsed_time_str}")
        folder_name = f"{true_column_names}_{selected_column}_feature_{feature}_horizon_{horizon}_local_scaler_type{local_scaler_type}_freq{freq}"
        path = f'/content/{folder_name}/{model.__class__.__name__}/'
        nf.save(path=path, model_index=None, overwrite=True, save_dataset=True)
        if Path(path).exists():
            nf2 = NeuralForecast.load(path=path)
            prediction = nf2.predict().reset_index()
            prediction.head()
            prediction = nf2.predict()
            print(f'{path}のモデルによる予測: {prediction}')

        # ディレクトリのリスト
        directories_to_copy = []

        # f'/content/{folder_name}'が存在する場合は、'/content/drive/MyDrive'直下にコピー
        content_folder = f'/content/{folder_name}'
        if os.path.exists(content_folder):
            destination = os.path.join('/content/drive/MyDrive', os.path.basename(content_folder))
            directories_to_copy.append((content_folder, destination))

        # '/content/lightning_logs'が存在する場合は、'/content/drive/MyDrive/{folder_name}/lightning_logs'にコピー
        lightning_logs_dir = '/content/lightning_logs'
        if os.path.exists(lightning_logs_dir):
            destination = os.path.join('/content/drive/MyDrive', folder_name, 'lightning_logs')
            directories_to_copy.append((lightning_logs_dir, destination))

        # ディレクトリをコピーする処理
        for source, destination in directories_to_copy:
            if os.path.exists(destination):
                try:
                    shutil.rmtree(destination)
                    print(f"既存のディレクトリ {destination} を削除しました。")
                except Exception as e:
                    print(f'ディレクトリ {destination} の削除中にエラーが発生しました: {str(e)}')
            if not os.path.exists(destination):
                try:
                    os.makedirs(os.path.dirname(destination), exist_ok=True)
                    shutil.copytree(source, destination)
                    print(f"ディレクトリ {source} のコピーが {destination} に完了しました。")
                except Exception as e:
                    print(f'ディレクトリ {source} のコピー中にエラーが発生しました: {str(e)}')
        pbar.update(1)
except Exception as e:
    print(f'モデルのロード中にエラーが発生しました: {str(e)}')
# Out:
# ...
# Epoch 399: 100%|██████████| 1/1 [00:02<00:00,  0.39it/s, v_num=0, train_loss_step=0.873, train_loss_epoch=0.873, valid_loss=0.837]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=68986)
# ...
# Epoch 499: 100%|██████████| 1/1 [00:02<00:00,  0.47it/s, v_num=0, train_loss_step=0.820, train_loss_epoch=0.814, valid_loss=0.919]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=68986)
# ...
# Epoch 599: 100%|██████████| 1/1 [00:01<00:00,  0.50it/s, v_num=0, train_loss_step=0.779, train_loss_epoch=0.782, valid_loss=1.010]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=68986)
# ...
# Epoch 699: 100%|██████████| 1/1 [00:03<00:00,  0.25it/s, v_num=0, train_loss_step=0.746, train_loss_epoch=0.740, valid_loss=0.939]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...

# %%
#@title モデルの再学習
# %%time
# モデルの保存先ディレクトリ
model_dir = "/content/drive/MyDrive/LOTO_num4_N1/AutoRNN"

# 更新されたデータ
updated_data = Y_train_df.tail(10)

# モデルのロード
if os.path.exists(model_dir):
    nf = NeuralForecast.load(model_dir)

    # モデルの更新
    nf.fit(df=updated_data)

    # モデルの保存
    nf.save(path=model_dir, overwrite=True)
else:
    print(f'モデルのディレクトリ {model_dir} が存在しません。')
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: UserWarning:
#
# Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: UserWarning:
#
# Attribute 'valid_loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['valid_loss'])`.
#
# INFO:lightning_fabric.utilities.seed:Seed set to 3
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# ...

# %%
#@title 再学習したモデルの予測
import plotly.graph_objects as go

# 再度予測を行う
prediction = nf.predict()
prediction["y"]=Y_test_df["y"].values
prediction
# Out:
# /usr/local/lib/python3.10/dist-packages/utilsforecast/processing.py:104: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /usr/local/lib/python3.10/dist-packages/utilsforecast/processing.py:104: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /usr/local/lib/python3.10/dist-packages/utilsforecast/processing.py:104: PerformanceWarning:
#
# ...

# %%
#@title 予測の可視化
import plotly.graph_objects as go

# 実測値と予測値を取得
y_real = prediction["y"]
y_pred = prediction["autornn"]

# データをプロット
fig = go.Figure()

# 実測値をプロット
fig.add_trace(go.Scatter(y=y_real, mode='lines', name='実測値'))

# 予測値をプロット
fig.add_trace(go.Scatter(y=y_pred, mode='lines', name='予測値'))

# タイトルと軸ラベルを設定
fig.update_layout(title='実測値と予測値の比較', xaxis_title='Index', yaxis_title='Value')

# プロットを表示
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
