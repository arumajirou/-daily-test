# %% [markdown]
# <a href="https://colab.research.google.com/github/arumajirou/-daily-test/blob/main/%E4%BA%88%E6%B8%AC%E5%99%A82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cython
# !pip install numba
# %load_ext Cython
from numba import jit
# !pip install gputil
# Out:
# ...
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython
# ...

# %%
# # ライブラリのインポート
# import psutil
# import humanize
# import os
# import GPUtil as GPU

# # RAMの使用状況を取得
# def printm():
#     process = psutil.Process(os.getpid())
#     print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " | Proc size: " + humanize.naturalsize(process.memory_info().rss))
#     print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))

# # GPUの使用状況を取得
# gpu = GPU.getGPUs()[0]

# # 使用状況を表示
# printm()

# %%
# ライブラリのインポート
import psutil

# CPUの使用率を取得
def print_cpu_usage():
    print("CPU usage: {}%".format(psutil.cpu_percent(interval=1)))

# 使用率を表示
print_cpu_usage()
# Out:
# CPU usage: 26.3%

# %%
# %%time
#@title ドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CPU times: user 33.3 ms, sys: 3.38 ms, total: 36.7 ms
# Wall time: 4.13 s

# %%
#@title uvの設定
# !pip install uv
# !uv venv
# On macOS and Linux.
# !source .venv/bin/activate
# Out:
# ...
# Using Python 3.10.12 interpreter at: /usr/bin/python3
# Creating virtualenv at: .venv
# Activate with: source .venv/bin/activate

# %%
# %%time
#@title uvの設定

#@title インストール
# !uv pip install -U causal-learn
# !uv pip install -U dowhy
# !uv pip install -U pycdt
# !uv pip install -U causallib
# !uv pip install -U networkx
# !uv pip install -U node2vec
# !uv pip install -U karateclub
# !uv pip install -U nashpy
# !uv pip install -U eppy
# !uv pip install -U feature_engine
# !uv pip install -U pycatch22
# !uv pip install -U pyts
# !uv pip install -U stumpy
# !uv pip install -U sktime
# !uv pip install -U cesium
# !uv pip install -U statsmodels
# !uv pip install -U tensorflow-probability
# !uv pip install -U problog
# !uv pip install -U pyro-ppl
# !uv pip install -U tsfresh
# !uv pip install -U featuretools
# !uv pip install -U pandas
# !uv pip install -U urllib3
# !uv pip install -U dask
# !uv pip install -U dask-ml
# !uv pip install -U kneed
# !uv pip install -U ruptures
# !uv pip install -U persim
# !uv pip install -U pywavelets
# !uv pip install -U scipy
# !uv pip install -U scikit-learn
# !uv pip install -U hmmlearn
# !uv pip install -U torch torchvision
# !uv pip install -U neuralforecast
# !uv pip install -U japanera
# !uv pip install -U polars
# !uv pip install -U autofeat
# !uv pip install -U CausalImpact
# !uv pip install -U pyfinance
# !uv pip install -U THINC
# !uv pip install -U hurst
# !uv pip install -U tsfedl
# !uv pip install -U egttools
# !uv pip install -U gambit
# !uv pip install -U pyentrp
# !uv pip install -U nolds
# !uv pip install -U tsml
# !uv pip install -U seglearn
# !uv pip install -U bnlearn
# !uv pip install -U dask[dataframe]
# !uv pip install -U mkl
# !uv pip install -U numpy
# !uv pip install -U ripser
# !uv pip install -U scipy
# !uv pip install -U jpholiday
# !uv pip install -U  tensorflow
# !uv pip install -U  tslearn
# Out:
# Resolved 36 packages in 35ms
# Installed 36 packages in 214ms
#  + causal-learn==0.1.3.8
#  + clarabel==0.7.1
#  + contourpy==1.2.1
#  + cvxpy==1.4.2
#  + cycler==0.12.1
#  + cython==3.0.10
#  + dowhy==0.11.1
#  + ecos==2.0.13
#  + fonttools==4.51.0
#  + graphviz==0.20.3
#  + joblib==1.4.0
#  + kiwisolver==1.4.5
#  + matplotlib==3.8.4
#  + mpmath==1.3.0
#  + networkx==3.3
#  + numpy==1.26.4
#  + osqp==0.6.4
#  + packaging==24.0
#  + pandas==2.2.2
#  + patsy==0.5.6
#  + pillow==10.3.0
#  + pybind11==2.12.0
#  + pydot==2.0.0
#  + pyparsing==3.1.2
#  + python-dateutil==2.9.0.post0
#  + pytz==2024.1
#  + qdldl==0.1.7.post1
#  + scikit-learn==1.4.2
#  + scipy==1.13.0
#  + scs==3.2.4.post1
#  + six==1.16.0
#  + statsmodels==0.14.1
#  + sympy==1.12
#  + threadpoolctl==3.4.0
#  + tqdm==4.66.2
#  + tzdata==2024.1
# Resolved 40 packages in 32ms
# Installed 20 packages in 343ms
#  + certifi==2024.2.2
#  + charset-normalizer==3.3.2
#  + future==1.0.0
#  + idna==3.7
#  + latexcodec==3.0.0
# ...

# %%
# %%time
#@title pipでのインストール
# !pip install -U japanera
# !pip install -U pyprobables
# !pip install -U ray
# !pip install -U neuralforecast
# !pip install pytorch_lightning
# Out:
# ...
# CPU times: user 498 ms, sys: 77.1 ms, total: 575 ms
# Wall time: 1min 8s

# %%
# %%time

#@title インポート
# Pythonにパッケージの場所を教えます
import os
import sys
sys.path.append('/content/.venv/lib/python3.10/site-packages')

import pandas as pd

import jpholiday
# データ取得
import urllib.request  # URLを扱うためのライブラリ
from io import StringIO  # メモリ上のテキストストリームを扱うためのライブラリ

# 分散データ処理
import dask.dataframe as dd  # 大規模データの並列処理を行うためのライブラリ
from dask.distributed import Client  # Daskの分散コンピューティング環境を管理するためのライブラリ

# 日本語処理
import japanera  # 日本の元号を扱うためのライブラリ

# タイプヒント
from typing import List, Dict, Tuple, Optional  # 型ヒントを提供するためのライブラリ

# データ表示
import ipywidgets as widgets  # 対話的なウィジェットを作成するためのライブラリ
from IPython.display import display, HTML  # Jupyter環境での出力表示を制御するためのライブラリ

# 特徴量エンジニアリング
import featuretools as ft  # 自動的な特徴量生成を行うためのライブラリ
# import autofeat  # 自動的な特徴量生成と選択を行うためのライブラリ
from tsfresh import extract_features  # 時系列データから特徴量を抽出するためのライブラリ

# 機械学習と統計
import statsmodels.api as sm  # 統計モデルを扱うためのライブラリ
from sklearn import datasets  # scikit-learnが提供するデータセット
# import dask_ml.model_selection as dcv  # Daskを使用した機械学習のためのライブラリ
from kneed import KneeLocator  # Knee point（膝点）を見つけるためのライブラリ
from scipy import stats  # 科学技術計算を行うためのライブラリ

# 時系列分析
import stumpy  # 時系列データ分析のためのライブラリ
import sktime  # 時系列分析のための統合フレームワーク
import cesium  # 時系列データ分析のためのライブラリ
import ruptures as rpt  # 変化点検出のためのライブラリ
import pywt  # 離散ウェーブレット変換を行うためのライブラリ
import hmmlearn.hmm as hmm  # 隠れマルコフモデルを扱うためのライブラリ
from hurst import compute_Hc  # Hurst指数を計算するためのライブラリ
# import tsml  # 時系列データマイニングのためのライブラリ
import seglearn  # 時系列データとシーケンス学習のためのライブラリ

# ディープラーニング
import torch  # ディープラーニングのためのライブラリ
# import torchvision  # 画像処理のためのライブラリ

# 因果推論
# import causallearn as cl  # 因果推論のためのライブラリ
import dowhy  # 因果推論のためのライブラリ
import pycdt  # 因果推論のためのライブラリ
import causallib  # 因果推論のためのライブラリ
from causalimpact import CausalImpact  # 因果影響分析のためのライブラリ

# ネットワーク分析
# import networkx as nx  # ネットワーク構造の分析と可視化のためのライブラリ
# from node2vec import Node2Vec  # ネットワークデータの埋め込み学習のためのライブラリ
# import karateclub  # ネットワーク埋め込みと非負値行列因子分解のためのライブラリ
import nashpy as nash  # ゲーム理論のためのライブラリ
# import gambit  # ゲーム理論のためのライブラリ
# import egttools  # 進化ゲーム理論のためのライブラリ

# 確率的プログラミング
import tensorflow_probability as tfp  # 確率的推論と統計的分析のためのライブラリ
# import problog  # 確率的論理プログラミングのためのライブラリ
# import pyro  # 確率的プログラミングのためのライブラリ

# 複雑系分析
# from persim import plot_diagrams  # 持続ホモロジーのためのライブラリ
# from pyentrp import entropy as ent  # エントロピー計算のためのライブラリ
import nolds  # 非線形ダイナミクスと複雑系分析のためのライブラリ

# 金融分析
import pyfinance  # 金融データ分析のためのライブラリ

# その他
# import eppy  # EnergyPlusの入出力ファイルを扱うためのライブラリ
import urllib3  # HTTPクライアントのためのライブラリ
# import pycatch22  # キャッチ22特徴セットを計算するためのライブラリ
import datetime
import shutil
from pathlib import Path
from tqdm.notebook import tqdm
import time
from ray import tune
import multiprocessing
from neuralforecast.core import NeuralForecast

from neuralforecast.auto import (
    AutoRNN,
    AutoLSTM,
    AutoGRU,
    AutoTCN,
    AutoDeepAR,
    AutoDilatedRNN,
    AutoMLP,
    AutoNBEATS,
    AutoNBEATSx,
    AutoNHITS,
    AutoTFT,
    AutoVanillaTransformer,
    AutoInformer,
    AutoAutoformer,
    AutoFEDformer,
    AutoPatchTST,
    AutoTimesNet,
    AutoStemGNN,
    AutoHINT
)

from tsfresh import extract_features

from kneed import KneeLocator
import ruptures as rpt
from ruptures.detection import Pelt
import numpy as np
from nolds import lyap_r, corr_dim
import pywt
from hmmlearn import hmm

from sklearn.feature_selection import mutual_info_classif
from sklearn.cluster import KMeans
from sklearn.linear_model import BayesianRidge
from sklearn.decomposition import PCA, FastICA
from sklearn.ensemble import IsolationForest
from sklearn.impute import SimpleImputer
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

from scipy.stats import norm, poisson, expon
from scipy.signal import find_peaks, find_peaks_cwt
from scipy import interpolate
from scipy import fftpack,signal,stats

import traceback
from rich import print
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, median_absolute_error
from math import sqrt
import pandas as pd
import os
import shutil
import time
import datetime  as dt
import pytz


pd.options.display.float_format = "{:.2f}".format
# Out:
# CPU times: user 281 µs, sys: 0 ns, total: 281 µs
# Wall time: 285 µs

# %%
#@title データの作成

@jit(nopython=True)
def get_rokuyo(japanese_date) -> str:
    '''
    この関数は、日本の日付を受け取り、それを旧暦に変換し、対応する六曜を返します。

    :param japanese_date: 変換する日本の日付。
    :type japanese_date: japanera.JapaneseDate
    :return: 対応する六曜。
    :rtype: str
    '''
    # 日本の日付を旧暦に変換します。
    old_date = japanese_date.to_julian_date()

    # 旧暦の日と月を足し算します。
    month_day = int(old_date) % 100 + int(old_date * 100) % 100

    # 足し算した結果を6で割った余りを計算します。
    remainder = month_day % 6

    # 六曜のリストを定義します。これは日本の伝統的なカレンダーシステムです。
    rokuyo_list = ["大安", "赤口", "先勝", "友引", "先負", "仏滅"]

    # 余りの数に対応する六曜をリストから選び、それを返します。
    return rokuyo_list[remainder]

#@jit(nopython=True)
def make_numbers(num: int) -> pd.DataFrame:
    '''
    この関数は、指定したナンバーズ（数値型）をウェブから取得し、pandasのデータフレームに格納します。

    :param num: ウェブから取得するナンバーズの種類を指定します。int型。
    :return: 取得したナンバーズのデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # 指定されたナンバーズのデータをウェブから読み込みます。読み込んだデータはshift-jisでエンコードされています。
    df = pd.read_table('http://vvslot.com/download.php?m=777&f=numbers' + str(num) + '.txt', encoding="shift-jis", sep=",", names=["part", "date", "week", "eto", "抽選数字"], parse_dates=[1], dtype='object')

    # 新たなカラム"LOTO"を作成し、"num"と指定したナンバーズの種類（num）を連結した文字列を格納します。
    df["LOTO"] = "num" + str(num)

    # データフレームを"date"カラム（日付）に基づいてソート（並び替え）します。
    df = df.sort_values(by='date')

    # 抽選数字の各桁を新しいカラムに分割して格納します。例えば、抽選数字が"1234"の場合、"N1"には"1"、"N2"には"2"、"N3"には"3"、"N4"には"4"が格納されます。
    for i in range(4):
        df["N" + str(i + 1)] = df["抽選数字"].str[i]

    return df


#@jit(nopython=True)
def make_Bin5() -> pd.DataFrame:
    '''
    この関数は、ビンゴ5のデータをウェブから取得し、pandasのデータフレームに格納します。

    :return: 取得したビンゴ5のデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # ビンゴ5のデータをウェブから読み込みます。このデータはHTMLのテーブル形式です。
    url = 'http://vvslot.com/bingo5_data.php'
    df_Bin5 = pd.read_html(url)

    # 読み込んだデータ（HTMLのテーブル）の中から、10番目（インデックスは9）のテーブルを取得します。
    # 不要なカラム（"Ｎ5",'1等', '2等', '3等'）を削除します。
    df_Bin5 = df_Bin5[9].drop(["Ｎ5",'1等', '2等', '3等'], axis=1)

    # データフレームのカラム名を新しく設定します。
    df_Bin5.columns = ['part','date','N1','N2','N3','N4','N5','N6','N7','N8']

    # 'date'カラムのデータを日付型に変換します。この際、日付の形式を指定します。
    df_Bin5['date'] = pd.to_datetime(df_Bin5['date'], format='%Y年%m月%d日')

    # 新たなカラム"LOTO"を作成し、その値として"Bin5"を格納します。これは、このデータフレームがビンゴ5のデータであることを示します。
    df_Bin5["LOTO"] = "Bin5"

    return df_Bin5


#@jit(nopython=True)
def make_loto(name: str = "loto6", col: int = 9, ln: int = 6, b: int = 1) -> pd.DataFrame:
    '''
    この関数は、指定されたロト（例：loto6）のデータをウェブから取得し、pandasのデータフレームに格納します。

    :param name: 取得するロトの名前を指定します。デフォルトは"loto6"。str型。
    :param col: 取得するカラムの数を指定します。デフォルトは9。int型。
    :param ln: ナンバーの数を指定します。デフォルトは6。int型。
    :param b: ボーナスの数を指定します。デフォルトは1。int型。
    :return: 取得したロトのデータを格納したデータフレーム。pandas.DataFrame型。
    '''
    # データフレームのカラム名を作成します。"part"、"date"、ナンバー("N1"~"N6")、ボーナス("B1")を含みます。
    names = ["part", "date"] + ["N" + str(i) for i in range(1, ln + 1)] + ["B" + str(j) for j in range(1, b + 1)]

    # 指定されたロトのデータをウェブから読み込みます。読み込んだデータはshift-jisでエンコードされています。
    df = pd.read_table('https://' + name + '.thekyo.jp/data/' + name + '.csv', encoding="shift-jis",
 sep=",", skiprows=1, usecols=list(range(col)), parse_dates=[1], names=names)  # datetimeの選択

    # 新たなカラム"LOTO"を作成し、ロトの名前を格納します。これは、このデータフレームがどのロトのデータであることを示します。
    df["LOTO"] = name

    return df

@jit(nopython=True)
def one_hot_encode_week(df: pd.DataFrame) -> pd.DataFrame:
    '''
    この関数は、データフレームの'week'カラムをワンホットエンコーディングします。

    :param df: ワンホットエンコーディングを行うデータフレーム。pandas.DataFrame型。
    :return: 'week'カラムをワンホットエンコーディングしたデータフレーム。pandas.DataFrame型。
    '''
    # 'week'カラムの各値をワンホットエンコーディングします。これにより、'week'カラムの各値が新たなカラムとして追加されます。
    week_dummies = pd.get_dummies(df['week'], prefix='week')

    # オリジナルのデータフレームとワンホットエンコーディングしたデータフレームを連結します。
    df = pd.concat([df, week_dummies], axis=1)

    # 元の'week'カラムはもう必要ないので、データフレームから削除します。
    df.drop('week', axis=1, inplace=True)

    return df



def remove_directory(dir_path):
    """
    指定したディレクトリが存在する場合、それを削除します。

    Parameters:
    dir_path (str): 削除するディレクトリのパス

    Returns:
    None
    """
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)
        print(f"{dir_path} has been removed successfully.")
    else:
        print(f"No directory found at {dir_path}")

# %%
#@title データフレームの作成
# セレクトボックスの選択肢を設定します。各選択肢は宝くじの種類を表しています。
options = [
 ("num4", "num4"),
 ("num3", "num3"),
 ("Bin5", "Bin5"),
 ("loto6", "loto6"),
 ("loto7", "loto7"),
 ("miniloto", "miniloto"),
]


# ドロップダウンメニューを作成します。ユーザーはこのメニューから宝くじの種類を選択します。
# デフォルトで"Bin5"が選択されるようにvalueパラメータを設定します。
select_box = widgets.Dropdown(
 options=options,
 value="num4",
 description='LOTO:',
 disabled=False,
)


# セレクトボックスを表示します。ユーザーが選択するためのものです。
display(select_box)

# フィルタリングされたデータフレームを格納するためのグローバル変数を宣言します。
global_filtered_df = None

from IPython.display import display, HTML
# @jit(nopython=True)
def filter_dataframe(change: dict = None) -> None:
 '''
 選択された宝くじの種類に応じてデータフレームをフィルタリングする関数

 Args:
 change (dict, optional): ドロップダウンメニューの値が変更されたときに生成される辞書型のデータ。
 'new'キーは新しく選択された値を表します。デフォルトはNone。

 Returns:
 None: この関数は何も返しません。ただし、グローバル変数global_filtered_dfが更新されます。
 '''
 # グローバル変数を参照します
 global global_filtered_df
 # ドロップダウンメニューで新しく選択された宝くじの種類を取得します
 # changeがNoneの場合、デフォルトで"num4"を選択します
 selected_column = change['new'] if change else "num4"
 # データフレームをフィルタリングします。
 # 選択された宝くじの種類の列が1の行だけを残します。
 try: # ここからエラーハンドリングを追加
     global_filtered_df = df_encoded[df_encoded[selected_column] == 1]
 except NameError as e: # df_encodedが未定義の場合に発生する例外
     print(f"データフレームdf_encodedが未定義です。{e}")
     traceback.print_exc()
     raise e  # エラーを再度発生させてプログラムを終了します

 except KeyError as e: # 選択された宝くじの種類の列が存在しない場合に発生する例外
     print(f"データフレームdf_encodedに{selected_column}という列がありません。{e}")
     traceback.print_exc()
     raise e  # エラーを再度発生させてプログラムを終了します
 else: # 例外が発生しなかった場合に実行する処理
     # フィルタリングされたデータフレームをHTMLテーブルとして表示します。
     display(HTML(global_filtered_df.head().to_html()))
 finally: # 例外の有無に関わらず必ず実行する処理
     print(f"{selected_column}でフィルタリングしました。")

#@jit(nopython=True)
def select_df():
  '''
  セレクトボックスを表示し、ユーザーが宝くじの種類を選択できるようにする関数

  引数: なし
  戻り値: なし
  '''
  # セレクトボックスを表示します。ユーザーが選択するためのものです。
  display(select_box)

  # 選択された宝くじの種類が変わったときに上記の関数を呼び出すように設定します。
  # この操作は「observe」と呼ばれ、ドロップダウンメニューの値が変更されるたびにfilter_dataframe関数が呼び出されるようにします。
  select_box.observe(filter_dataframe, names='value')

  # 初期状態でfilter_dataframe関数を呼び出し、デフォルトの"Bin5"でフィルタリングします。
  filter_dataframe()
# Out:
# Dropdown(description='LOTO:', options=(('num4', 'num4'), ('num3', 'num3'), ('Bin5', 'Bin5'), ('loto6', 'loto6'…

# %%
# データフレームの作成
df_numbers4 = pd.DataFrame(make_numbers(4))  # ナンバーズ4のデータフレームを作成します
df_numbers3 = pd.DataFrame(make_numbers(3))  # ナンバーズ3のデータフレームを作成します
df_Bin5 = pd.DataFrame(make_Bin5())  # ビンゴ5のデータフレームを作成します
df_loto5 = pd.DataFrame(make_loto(name="miniloto", col=8, ln=5, b=1))  # ミニロトのデータフレームを作成します
df_loto6 = pd.DataFrame(make_loto())  # ロト6のデータフレームを作成します
df_loto7 = pd.DataFrame(make_loto(name="loto7", col=11, ln=7, b=2))  # ロト7のデータフレームを作成します

# データフレームの結合と日付での並び替え
df_sorted = pd.concat([df_loto5, df_loto6, df_loto7, df_numbers3, df_numbers4, df_Bin5]).sort_values('date')

# '抽選数字'カラムは不要なので削除します
df_sorted.drop('抽選数字', axis=1, inplace=True)

# データフレームを日付で並び替えます
df_sorted = df_sorted.sort_values(by='date')

# カテゴリ変数をワンホットエンコーディングします
df_encoded = pd.get_dummies(df_sorted, columns=['week', 'eto', 'LOTO'])

# Convert the num1 to num8 columns to integer type
df_encoded[['part','N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7','N8','B1', 'B2']] = df_encoded[['part','N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7','N8','B1', 'B2']].replace('missing', 0).replace([np.inf, -np.inf], np.nan).fillna(0).astype(int)


#@title データの情報
df_encoded.columns = df_encoded.columns.str.replace('LOTO_', '')
df_encoded.rename(columns={'miniloto': 'mini'}, inplace=True)

df_encoded.info()
#df_encoded=df_encoded[df_encoded.Bin5 == 1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16987 entries, 0 to 569
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   part    16987 non-null  int64
#  1   date    16987 non-null  datetime64[ns]
#  2   N1      16987 non-null  int64
#  3   N2      16987 non-null  int64
#  4   N3      16987 non-null  int64
#  5   N4      16987 non-null  int64
#  6   N5      16987 non-null  int64
#  7   B1      16987 non-null  int64
#  8   N6      16987 non-null  int64
#  9   N7      16987 non-null  int64
#  10  B2      16987 non-null  int64
#  11  N8      16987 non-null  int64
#  12  week_月  16987 non-null  bool
#  13  week_木  16987 non-null  bool
#  14  week_水  16987 non-null  bool
#  15  week_火  16987 non-null  bool
#  16  week_金  16987 non-null  bool
#  17  eto_仏滅  16987 non-null  bool
#  18  eto_先勝  16987 non-null  bool
#  19  eto_先負  16987 non-null  bool
#  20  eto_友引  16987 non-null  bool
#  21  eto_大安  16987 non-null  bool
# ...

# %%
select_df()
# Out:
# Dropdown(description='LOTO:', options=(('num4', 'num4'), ('num3', 'num3'), ('Bin5', 'Bin5'), ('loto6', 'loto6'…
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>part</th>
#       <th>date</th>
#       <th>N1</th>
#       <th>N2</th>
#       <th>N3</th>
#       <th>N4</th>
#       <th>N5</th>
#       <th>B1</th>
#       <th>N6</th>
#       <th>N7</th>
#       <th>B2</th>
#       <th>N8</th>
#       <th>week_月</th>
#       <th>week_木</th>
#       <th>week_水</th>
#       <th>week_火</th>
#       <th>week_金</th>
#       <th>eto_仏滅</th>
#       <th>eto_先勝</th>
#       <th>eto_先負</th>
#       <th>eto_友引</th>
#       <th>eto_大安</th>
#       <th>eto_赤口</th>
#       <th>Bin5</th>
#       <th>loto6</th>
#       <th>loto7</th>
#       <th>mini</th>
#       <th>num3</th>
#       <th>num4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1994-10-07</td>
#       <td>1</td>
# ...

# %%
# %%time
#@title カラムのチェック
columns_to_check = ["Bin5", "loto6", "loto7", "mini", "num3", "num4"]

# Trueになっているカラム名を見つける
true_columns = global_filtered_df[columns_to_check].apply(lambda row: row[row == True].index.tolist(), axis=1)

# 結果を変数に格納
true_column_names = true_columns.tolist()[0][0]

# 結果を表示
print(true_column_names)
# Out:
# num4
# CPU times: user 1.67 s, sys: 18.6 ms, total: 1.69 s
# Wall time: 2.59 s

# %%
# %%time
#@title　予測データの絞り込み

# 選択可能なカラムのリストを作成します
columns = ['N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'B1', 'B2']

# プルダウンメニューを作成します
dropdown = widgets.Dropdown(options=columns, value=columns[0])

# 出力エリアを作成します
output = widgets.Output()

# 選択したデータフレームを保存するための変数を作成します
selected_df_pre = global_filtered_df[['date', columns[0]]]

# 選択したカラムを保存するための変数を作成します
selected_column = columns[0]

# プルダウンメニューの値が変更されたときの動作を定義します
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        # 出力エリアをクリアします
        output.clear_output()

        # 選択したカラムとdateカラムのデータフレームを作成します
        global selected_df_pre, selected_column
        selected_column = change['new']
        selected_df_pre = global_filtered_df[['date', selected_column]]

        # 新しいデータフレームを表示します
        with output:
            display(selected_df_pre)
    return selected_df_pre

# プルダウンメニューの値が変更されたときにon_change関数を呼び出します
dropdown.observe(on_change)

# プルダウンメニューと出力エリアを表示します
display(dropdown)
display(output)
# Out:
# Dropdown(options=('N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'B1', 'B2'), value='N1')
# Output()
# CPU times: user 11.4 ms, sys: 1.92 ms, total: 13.3 ms
# Wall time: 21.3 ms

# %%
selected_df_pre
# Out:
#            date  N1
# 0    1994-10-07   1
# 1    1994-10-14   7
# 2    1994-10-21   0
# 3    1994-10-28   0
# 4    1994-11-04   0
# ...         ...  ..
# 6441 2024-04-08   2
# 6442 2024-04-09   1
# 6443 2024-04-10   4
# 6444 2024-04-11   2
# 6445 2024-04-12   8
#
# [6446 rows x 2 columns]

# %%
#@title データの情報
# pandasのto_datetime関数を使用して、dateカラムを日時型に変換します
global_filtered_df['date'] = pd.to_datetime(global_filtered_df['date'])

# dateカラムのデータ型を確認します
print(global_filtered_df['date'].dtype)

global_filtered_df.info()
# Out:
# datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 6446 entries, 0 to 6445
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   part    6446 non-null   int64
#  1   date    6446 non-null   datetime64[ns]
#  2   N1      6446 non-null   int64
#  3   N2      6446 non-null   int64
#  4   N3      6446 non-null   int64
#  5   N4      6446 non-null   int64
#  6   N5      6446 non-null   int64
#  7   B1      6446 non-null   int64
#  8   N6      6446 non-null   int64
#  9   N7      6446 non-null   int64
#  10  B2      6446 non-null   int64
#  11  N8      6446 non-null   int64
#  12  week_月  6446 non-null   bool
#  13  week_木  6446 non-null   bool
#  14  week_水  6446 non-null   bool
#  15  week_火  6446 non-null   bool
#  16  week_金  6446 non-null   bool
#  17  eto_仏滅  6446 non-null   bool
#  18  eto_先勝  6446 non-null   bool
#  19  eto_先負  6446 non-null   bool
#  20  eto_友引  6446 non-null   bool
# ...

# %%
#@title カラム名の変更
# %%time
merged_df =selected_df_pre
merged_df["date"]=global_filtered_df["date"]
selected_df = merged_df.sort_index()
selected_df = merged_df.rename(columns={selected_column: 'y', 'date': 'ds'})
selected_df["unique_id"]=0
# 重複したカラムを削除
selected_df = selected_df.loc[:,~selected_df.columns.duplicated()]

# 'y'と'ds'というカラムが存在するか確認
if 'y' in selected_df.columns and 'ds' in selected_df.columns and 'unique_id' in selected_df.columns:
    print("'y'と'ds'と'unique_id'のカラムが存在します。")
else:
    print("'y'と'ds'と'unique_id'のカラムが存在しません。")
    merged_df["date"]=global_filtered_df["date"]
    selected_df = merged_df.sort_index()
    selected_df = merged_df.rename(columns={selected_column: 'y', 'date': 'ds'})
# Out:
# 'y'と'ds'と'unique_id'のカラムが存在します。
# CPU times: user 6.35 ms, sys: 0 ns, total: 6.35 ms
# Wall time: 7.46 ms

# %%
#@title データの分割
from ipywidgets import interact, IntSlider

# Define global variables
selected_df_ = None
Y_train_df = None
Y_test_df = None
feature = None
leng = None
horizon = None
freq = None

# Define a function to update the variables
def update_variables(df_leng, test_size):
    global selected_df_, Y_train_df, Y_test_df, feature, leng, horizon, freq
    selected_df_ = selected_df.tail(df_leng)
    Y_train_df = selected_df_.iloc[:-test_size]
    Y_test_df = selected_df_.iloc[-test_size:]
    feature = len(Y_train_df.columns)
    leng = len(Y_train_df)
    horizon = test_size
    freq = 'D'
    print(f"df_leng: {df_leng}, test_size: {test_size}, feature: {feature}, leng: {leng}, horizon: {horizon}, freq: {freq}")

# Create sliders
df_leng_slider = IntSlider(min=0, max=len(selected_df), step=10, value=7100)
test_size_slider = IntSlider(min=0, max=10, step=1, value=2)

# Use interact function to create interactive widgets
interact(update_variables, df_leng=df_leng_slider, test_size=test_size_slider)
# Out:
# interactive(children=(IntSlider(value=6446, description='df_leng', max=6446, step=10), IntSlider(value=2, desc…
# <function __main__.update_variables(df_leng, test_size)>

# %%
print(f"訓練データの数: {len(Y_train_df)}")
print(f"テストデータの数: {len(Y_test_df)}")
print(f"カラムの数: {len(Y_test_df.columns)}")
print(f"特徴量: {feature}")
print(f"訓練数: {leng}")
# Out:
# 訓練データの数: 6444
# テストデータの数: 2
# カラムの数: 3
# 特徴量: 3
# 訓練数: 6444

# %%
#@title モデル定義
cpus = multiprocessing.cpu_count()
gpus = torch.cuda.device_count()


models =[
    AutoRNN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoLSTM(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoGRU(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTCN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoDeepAR(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoDilatedRNN(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoMLP(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNBEATS(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNBEATSx(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoNHITS(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTFT(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoVanillaTransformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoInformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoAutoformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoFEDformer(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    #AutoPatchTST(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoTimesNet(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
    AutoStemGNN(config=None, n_series=1, h=horizon, cpus=cpus, gpus=gpus, verbose=False)
    # AutoHINT(config=None, h=horizon, cpus=cpus, gpus=gpus, verbose=False),
]
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/parsing.py:199: Attribute 'valid_loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['valid_loss'])`.

# %%
from rich import print

# ディレクトリとエラーメッセージを定義します
directory = "/path/to/directory"
e = "Permission denied"

# richのprint関数を使用して、エラーメッセージを強調表示して出力します
print(f"[bold red]ディレクトリ {directory} でエラーが発生しました: {e}[/bold red]")
# Out:
# ディレクトリ /path/to/directory でエラーが発生しました: Permission denied

# %%
#@title モデルの再学習と予測の評価　関数

parent_folder ="/content/drive/MyDrive/num4_N1_3_6444"
retrain = False # @param {type:"boolean"}
y_test=Y_test_df.y.values
error_directories=[]
error_directories2=[]
def evaluate_models(parent_folder,true_column_names,selected_column,Y_train_df,y_test,gpus,cpus,retrain=False):
    """
    この関数は、指定したディレクトリに保存されているモデルのパフォーマンスを評価します。
    モデルを再学習するか、予測のためにだけロードするかを選択できます。

    引数:
    parent_folder (str): モデルが保存されている親ディレクトリ。
    retrain (bool): Trueの場合、モデルは再学習されます。Falseの場合、モデルは予測のためにだけロードされます。

    戻り値:
    csv_path
    """
    # 使用例
    dir_path = "/content/lightning_logs"
    remove_directory(dir_path)
    parent_directory = os.path.dirname(parent_folder)
    save_folder_name = os.path.basename(parent_folder)
    # 結果用のデータフレームを初期化
    # results_df = pd.DataFrame(columns=['Model', 'MSE', 'MAE', 'R2', 'RMSE', 'MAPE', 'MedAE'])
    results_df = pd.DataFrame(columns=['Model', 'MSE', 'MAE', 'R2', 'RMSE', 'MAPE', 'MedAE', 'Feature', 'Time', 'loto', 'N', '学習量'])

    # ディレクトリ内のすべての項目をリストアップ
    items = os.listdir(parent_folder)
    print("$"*100,"\n",f"items={items}")
    # ディレクトリをフィルタリング
    directories = [item for item in items if os.path.isdir(os.path.join(parent_folder, item)) and item != 'lightning_logs']
    error_directories = []
    error_directories2 = []
    # 各ディレクトリ（モデル）に対してループ
    for directory in tqdm(directories):
        print("*"*100,"\n",f"ディレクトリ {directory} の処理を開始します。")
        try:
            first_string = directory.split('_')[0]
            save_directory = f'{parent_folder}/'
            print("-"*100,"\n",f"save_directory ={save_directory}")
            # 現在の時刻を取得
            start_time = time.time()

            # モデルをロード
            model_path = os.path.join(parent_folder, directory)
            print("-"*100,"\n",f"model_path ={model_path}")
            nf = NeuralForecast.load( model_path)

            # 指定された場合はモデルを再学習
            if retrain:
                print("モデルの再学習を開始します...")
                nf.fit(df=Y_train_df)

                elapsed_time = time.time() - start_time
                elapsed_time_str = str(dt.timedelta(seconds=int(elapsed_time)))
                print(f"再学習にかかった時間: {elapsed_time_str}")

                save_directory = f"{parent_directory}/{true_column_names}_{selected_column}_{len(Y_train_df.columns)}_{len(Y_train_df)}/"
                print("-"*100,"\n",f"save_directory ={save_directory}")
                save_path = save_directory +f'{first_string}_{true_column_names}_{selected_column}_{len(Y_train_df.columns)}_{len(Y_train_df)}_{elapsed_time_str}'
                print("."*100,"\n",f"save_path ={save_path}")

                print(f"{save_path}\nにモデルを保存しています...")
                nf.save(path=save_path, overwrite=True)
                print(f"{save_path}\nにモデルの保存が完了しました。")

                print(f"{save_path}\nのモデルを読み込んでいます...")
                nf = NeuralForecast.load(save_path)
                print(f"{save_path}\nのモデルの読み込みが完了しました。")


            # 予測を実行
            start_time = time.time()
            y_pred = nf.predict()
            elapsed_time_pre = time.time() - start_time
            elapsed_time_str_pre = str(dt.timedelta(seconds=int(elapsed_time_pre)))
            y_pred_values = round(y_pred.iloc[:, 1])
            y_pred_values = y_pred_values.values
            # y_pred_values = y_pred.iloc[:, 1].values
            # 値を小数点以下2桁に丸める
            #y_pred_values = [round(value, 2) for value in y_pred_values]
            # 評価指標を計算
            mse = mean_squared_error(y_test, y_pred_values)
            mae = mean_absolute_error(y_test, y_pred_values)
            r2 = r2_score(y_test, y_pred_values)
            rmse = sqrt(mse)
            mape = np.mean(np.abs((y_test - y_pred_values) / y_test)) * 100
            medae = median_absolute_error(y_test, y_pred_values)

            if retrain:
                elapsed_time_str=elapsed_time_str
            else:
                elapsed_time_str=elapsed_time_str_pre


            # 結果をデータフレームに追加
            new_row = pd.DataFrame({
                'Model': [directory],
                'MSE': [mse],
                'MAE': [mae],
                'R2': [r2],
                'RMSE': [rmse],
                'MAPE': [mape],
                'MedAE': [medae],
                'Feature': [len(Y_train_df.columns)],
                'Time': [elapsed_time_str],
                'loto': [true_column_names],
                'N': [selected_column],
                '学習量': [len(Y_train_df)],
                'Predicted': [y_pred_values.tolist()],
                'Measured': [y_test.tolist()]
            })
            results_df = pd.concat([results_df, new_row], ignore_index=True)
        except Exception as e:
            print(f"ディレクトリ {directory} でエラーが発生しました: {e}")
            traceback.print_exc()
            # エラーが発生したディレクトリの名前をリストに追加
            error_directories.append(directory)
            error_directories2.append(e)
            continue

    # 平均指標を計算
    results_df['Average_All'] = results_df[['MSE', 'MAE', 'R2', 'RMSE', 'MAPE', 'MedAE']].mean(axis=1)
    results_df['Average_MSE_RMSE'] = results_df[['MSE', 'RMSE']].mean(axis=1)

    # 平均MSEとRMSEでソート
    sorted_df = results_df.sort_values(by='Average_MSE_RMSE')
    error_df = pd.DataFrame(list(zip(error_directories, error_directories2)), columns=['dir', 'error'])
    error_csv_path = f"{parent_folder}/error_directories.csv"
    error_df.to_csv(f"{parent_folder}/error_directories.csv", index=False)
    try:
        if retrain:
            # コピー元のパス
            src = "/content/lightning_logs"
            dst= save_directory + f"lightning_logs"
            print(dst)
            # ディレクトリをコピー
            shutil.copytree(src, dst)
            print(f"{src}\\nは {dst} に保存されました")
            csv_path=save_directory+f"{save_folder_name}_{len(Y_train_df)}_{elapsed_time_str}.csv"
            print(f"retrain_csv_path ={csv_path}")
            # 結果をCSVファイルに保存
            sorted_df.to_csv(csv_path, index=False)
            print(f"{csv_path}\\nにモデルの評価CSVの保存が完了しました。","\\n","-"*100,"\\n")
        else:
            csv_path=save_directory+f"{save_folder_name}.csv"
            print(f"csv_path ={csv_path}")
            # 結果をCSVファイルに保存
            sorted_df.to_csv(csv_path, index=False)

    except FileNotFoundError as fnf_error:
        print(f"ファイルが見つかりません: {fnf_error}")

        traceback.print_exc()
        raise e

    except Exception as e:
        print(f"An error occurred: {e}")
        traceback.print_exc()
        raise e
    return csv_path,error_csv_path

import os
import glob

def get_directories(path, pattern):
    """
    指定したパスの階層にある、指定したパターンという文字列が含まれたディレクトリの一覧を取得する関数

    Parameters
    ----------
    path : str
        ディレクトリのパス
    pattern : str
        検索するパターン

    Returns
    -------
    list
        パターンに一致するディレクトリの一覧
    """
    try:
        # パスとパターンを組み合わせて検索するパスを作成
        search_path = os.path.join(path, pattern)
        # パターンに一致するディレクトリの一覧を取得
        directories = [d for d in glob.glob(search_path) if os.path.isdir(d)]
        return directories
    except Exception as e:
        # エラーメッセージを表示
        print(f"エラーが発生しました: {e}")
        return []

# %%
retrain = False #@param {type:"boolean"}

# %%
#@title モデルの再学習、予測、評価

from pytorch_lightning import Trainer
from datetime import datetime
y_test=Y_test_df.y.values

# テスト
path = "/content/drive/MyDrive/"
pattern = "*num4*"
directories=get_directories(path, pattern)
print(directories)
# directories =["/content/drive/MyDrive/num4_N1_f3_h2_standard_98_le"]
# 空のデータフレームを作成
model_evaluation_df = pd.DataFrame()
model_evaluation_df_error = pd.DataFrame()
# 各ディレクトリの処理
for i in tqdm(directories):
    print("#"*100,"\n",f"ディレクトリ {i} の処理を開始します。")
    csv_path ,error_csv_path= evaluate_models(i,true_column_names, selected_column,
                               Y_train_df, y_test,gpus,cpus,
                               retrain=retrain)
    print("#"*100,"\n",f"ディレクトリ {i} の処理が完了しました。")

    # csvファイルからデータフレームを作成
    model_performance_df = pd.read_csv(csv_path)
    model_evaluation_df = pd.concat([model_evaluation_df,
                                     model_performance_df])
    # csvファイルからデータフレームを作成
    error_df_error = pd.read_csv(error_csv_path)
    model_evaluation_df_error = pd.concat([model_evaluation_df_error,
                                     error_df_error])
# 'Average_MSE_RMSE'カラムの値でソート
model_evaluation_df = model_evaluation_df.sort_values(by='Average_MSE_RMSE')

# 現在の日時を取得
now = datetime.now(pytz.timezone('Asia/Tokyo'))

# 日時を文字列に変換（例：2024_04_14_00_29_50）
timestamp_str = now.strftime("%Y_%m_%d_%H_%M_%S")
model_evaluation_df_path =(    f'/content/drive/MyDrive/'
    f'model_evaluation_{true_column_names}_{selected_column}_{timestamp_str}.csv')

# 結果を表示
model_evaluation_df.to_csv(model_evaluation_df_path,index=False
)
# Out:
# [
#     '/content/drive/MyDrive/num4_N1_f3_h2_standard_998_le',
#     '/content/drive/MyDrive/num4_N1_f3_h2_standard_98_le',
#     '/content/drive/MyDrive/num4_N1_f3_h2_standard_6443_le',
#     '/content/drive/MyDrive/num4_N1_3_6444',
#     '/content/drive/MyDrive/num4_N1_3_448'
# ]
#   0%|          | 0/5 [00:00<?, ?it/s]
# ####################################################################################################
#  ディレクトリ /content/drive/MyDrive/num4_N1_f3_h2_standard_998_le の処理を開始します。
# /content/lightning_logs has been removed successfully.
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#  items=['lightning_logs', 'LOTO_num4_N1_feature_3_horizon_2_scaler_standard_freq_D_len_5_.csv',
# 'LOTO_num4_N1_feature_3_horizon_2_scaler_standard_freq_D_len_6443_.csv', 'AutoRNN_998_0:03:13',
# 'AutoLSTM_998_0:04:53', 'AutoGRU_998_0:03:15', 'AutoTCN_998_0:03:26', 'AutoDeepAR_998_0:04:39',
# ...

# %%
print(model_evaluation_df.info())
pred_df=model_evaluation_df[["Predicted","Measured"]]
print(pred_df.info())
pred_df

# %%
# %%time
#@title モデルの作成

# 'standard': 標準化スケーラ（平均0、分散1にスケーリング）
# 'robust': ロバストスケーラ（中央値と四分位範囲に基づくスケーリング）
# 'robust-iqr': IQRロバストスケーラ（四分位範囲に基づくスケーリング）
# 'minmax': Min-Maxスケーラ（最小値0、最大値1にスケーリング）
# 'boxcox': Box-Cox変換（正規分布に近づけるための変換）

try:
    pbar = tqdm(total=len(models), desc="モデルの処理")

    for model in models:
        start_time = time.time()
        print("+"*100)
        print(f"モデル名: {model.__class__.__name__}")
        print("+"*100)
        nf = NeuralForecast(models=[model], freq=freq, local_scaler_type=local_scaler_type)
        nf.fit(df=Y_train_df)
        elapsed_time = time.time() - start_time
        elapsed_time_str = str(datetime.timedelta(seconds=int(elapsed_time)))
        print(f"{model.__class__.__name__}の処理時間: {elapsed_time_str}")
        folder_name = f"{true_column_names}_{selected_column}_f{feature}_h{horizon}_{local_scaler_type}_{leng}_le"
        path = f'/content/{folder_name}/{model.__class__.__name__}_{leng}_{elapsed_time_str}/'
        nf.save(path=path, model_index=None, overwrite=True, save_dataset=True)
        if Path(path).exists():
            nf2 = NeuralForecast.load(path=path)
            prediction = nf2.predict().reset_index()
            prediction.head()
            prediction = nf2.predict()
            print(f'{path}のモデルによる予測: {prediction}')

        # ディレクトリのリスト
        directories_to_copy = []

        # f'/content/{folder_name}'が存在する場合は、'/content/drive/MyDrive'直下にコピー
        content_folder = f'/content/{folder_name}'
        if os.path.exists(content_folder):
            destination = os.path.join('/content/drive/MyDrive', os.path.basename(content_folder))
            directories_to_copy.append((content_folder, destination))

        # '/content/lightning_logs'が存在する場合は、'/content/drive/MyDrive/{folder_name}/lightning_logs'にコピー
        lightning_logs_dir = '/content/lightning_logs'
        if os.path.exists(lightning_logs_dir):
            destination = os.path.join('/content/drive/MyDrive', folder_name, 'lightning_logs')
            directories_to_copy.append((lightning_logs_dir, destination))

        # ディレクトリをコピーする処理
        for source, destination in directories_to_copy:
            if os.path.exists(destination):
                try:
                    shutil.rmtree(destination)
                    print(f"既存のディレクトリ {destination} を削除しました。")
                except Exception as e:
                    print(f'ディレクトリ {destination} の削除中にエラーが発生しました: {str(e)}')
                    traceback.print_exc()
                    raise e  # エラーを再度発生させてプログラムを終了します
            if not os.path.exists(destination):
                try:
                    os.makedirs(os.path.dirname(destination), exist_ok=True)
                    shutil.copytree(source, destination)
                    print(f"ディレクトリ {source} のコピーが {destination} に完了しました。")
                except Exception as e:
                    print(f'ディレクトリ {source} のコピー中にエラーが発生しました: {str(e)}')
                    traceback.print_exc()
                    raise e  # エラーを再度発生させてプログラムを終了します
        pbar.update(1)
except Exception as e:
    print(f'モデルのロード中にエラーが発生しました: {str(e)}')
    traceback.print_exc()
    raise e  # エラーを再度発生させてプログラムを終了します
# Out:
# モデルの処理:   0%|          | 0/17 [00:00<?, ?it/s]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# モデル名: AutoRNN
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# モデルのロード中にエラーが発生しました: name 'local_scaler_type' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <module>
#
# NameError: name 'local_scaler_type' is not defined
